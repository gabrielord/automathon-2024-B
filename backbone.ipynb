# %%
# !git clone https://github.com/kiyoshi2000/automathon-2024-B.git
# Out:
# Cloning into 'automathon-2024-B'...
# remote: Enumerating objects: 401, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 401 (delta 143), reused 142 (delta 142), pack-reused 254
# Receiving objects: 100% (401/401), 947.36 KiB | 18.22 MiB/s, done.
# Resolving deltas: 100% (229/229), done.

# %%
# !pip install -r automathon-2024-B/requirements.txt
# Out:
# Requirement already satisfied: appdirs==1.4.4 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 1)) (1.4.4)
# Collecting appnope==0.1.4 (from -r automathon-2024-B/requirements.txt (line 2))
#   Downloading appnope-0.1.4-py2.py3-none-any.whl.metadata (908 bytes)
# Requirement already satisfied: asttokens==2.4.1 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 3)) (2.4.1)
# Requirement already satisfied: certifi==2024.2.2 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 4)) (2024.2.2)
# Requirement already satisfied: charset-normalizer==3.3.2 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: click==8.1.7 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 6)) (8.1.7)
# Collecting comm==0.2.2 (from -r automathon-2024-B/requirements.txt (line 7))
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting contourpy==1.2.1 (from -r automathon-2024-B/requirements.txt (line 8))
#   Downloading contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: cycler==0.12.1 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 9)) (0.12.1)
# Collecting debugpy==1.8.1 (from -r automathon-2024-B/requirements.txt (line 10))
#   Downloading debugpy-1.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: decorator==5.1.1 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 11)) (5.1.1)
# Requirement already satisfied: docker-pycreds==0.4.0 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 12)) (0.4.0)
# Collecting exceptiongroup==1.2.1 (from -r automathon-2024-B/requirements.txt (line 13))
#   Downloading exceptiongroup-1.2.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: executing==2.0.1 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 14)) (2.0.1)
# Collecting filelock==3.13.4 (from -r automathon-2024-B/requirements.txt (line 15))
#   Downloading filelock-3.13.4-py3-none-any.whl.metadata (2.8 kB)
# Collecting fonttools==4.51.0 (from -r automathon-2024-B/requirements.txt (line 16))
#   Downloading fonttools-4.51.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 3.9 MB/s eta 0:00:00a 0:00:01
# Collecting fsspec==2024.3.1 (from -r automathon-2024-B/requirements.txt (line 17))
#   Downloading fsspec-2024.3.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: gitdb==4.0.11 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 18)) (4.0.11)
# Collecting GitPython==3.1.43 (from -r automathon-2024-B/requirements.txt (line 19))
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: huggingface-hub==0.22.2 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 20)) (0.22.2)
# Collecting idna==3.7 (from -r automathon-2024-B/requirements.txt (line 21))
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting ipykernel==6.29.4 (from -r automathon-2024-B/requirements.txt (line 22))
#   Downloading ipykernel-6.29.4-py3-none-any.whl.metadata (6.3 kB)
# Collecting ipython==8.24.0 (from -r automathon-2024-B/requirements.txt (line 23))
#   Downloading ipython-8.24.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: jedi==0.19.1 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 24)) (0.19.1)
# Collecting Jinja2==3.1.3 (from -r automathon-2024-B/requirements.txt (line 25))
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting jupyter_client==8.6.1 (from -r automathon-2024-B/requirements.txt (line 26))
#   Downloading jupyter_client-8.6.1-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter_core==5.7.2 (from -r automathon-2024-B/requirements.txt (line 27))
#   Downloading jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: kiwisolver==1.4.5 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 28)) (1.4.5)
# Collecting MarkupSafe==2.1.5 (from -r automathon-2024-B/requirements.txt (line 29))
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting matplotlib==3.8.4 (from -r automathon-2024-B/requirements.txt (line 30))
#   Downloading matplotlib-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting matplotlib-inline==0.1.7 (from -r automathon-2024-B/requirements.txt (line 31))
#   Downloading matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: mpmath==1.3.0 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 32)) (1.3.0)
# Collecting nest-asyncio==1.6.0 (from -r automathon-2024-B/requirements.txt (line 33))
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting networkx==3.3 (from -r automathon-2024-B/requirements.txt (line 34))
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy==1.26.4 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 35)) (1.26.4)
# Collecting packaging==24.0 (from -r automathon-2024-B/requirements.txt (line 36))
#   Downloading packaging-24.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas==2.2.2 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 37)) (2.2.2)
# Collecting parso==0.8.4 (from -r automathon-2024-B/requirements.txt (line 38))
#   Downloading parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting pexpect==4.9.0 (from -r automathon-2024-B/requirements.txt (line 39))
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pillow==10.3.0 (from -r automathon-2024-B/requirements.txt (line 40))
#   Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting platformdirs==4.2.1 (from -r automathon-2024-B/requirements.txt (line 41))
#   Downloading platformdirs-4.2.1-py3-none-any.whl.metadata (11 kB)
# Collecting prompt-toolkit==3.0.43 (from -r automathon-2024-B/requirements.txt (line 42))
#   Downloading prompt_toolkit-3.0.43-py3-none-any.whl.metadata (6.5 kB)
# Collecting protobuf==4.25.3 (from -r automathon-2024-B/requirements.txt (line 43))
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting psutil==5.9.8 (from -r automathon-2024-B/requirements.txt (line 44))
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: ptyprocess==0.7.0 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 45)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 46)) (0.2.2)
# Collecting pyav==12.0.5 (from -r automathon-2024-B/requirements.txt (line 47))
#   Downloading pyav-12.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.4 kB)
# Requirement already satisfied: Pygments==2.17.2 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 48)) (2.17.2)
# Collecting pyparsing==3.1.2 (from -r automathon-2024-B/requirements.txt (line 49))
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 50)) (2.9.0.post0)
# Collecting pytz==2024.1 (from -r automathon-2024-B/requirements.txt (line 51))
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: PyYAML==6.0.1 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 52)) (6.0.1)
# Collecting pyzmq==26.0.2 (from -r automathon-2024-B/requirements.txt (line 53))
#   Downloading pyzmq-26.0.2-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: requests==2.31.0 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 54)) (2.31.0)
# Requirement already satisfied: safetensors==0.4.3 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 55)) (0.4.3)
# Collecting sentry-sdk==2.0.1 (from -r automathon-2024-B/requirements.txt (line 56))
#   Downloading sentry_sdk-2.0.1-py2.py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: setproctitle==1.3.3 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 57)) (1.3.3)
# Requirement already satisfied: six==1.16.0 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 58)) (1.16.0)
# Requirement already satisfied: smmap==5.0.1 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 59)) (5.0.1)
# Collecting stack-data==0.6.3 (from -r automathon-2024-B/requirements.txt (line 60))
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: sympy==1.12 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 61)) (1.12)
# Requirement already satisfied: timm==0.9.16 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 62)) (0.9.16)
# Collecting torch==2.3.0 (from -r automathon-2024-B/requirements.txt (line 63))
#   Downloading torch-2.3.0-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchaudio==2.3.0 (from -r automathon-2024-B/requirements.txt (line 64))
#   Downloading torchaudio-2.3.0-cp310-cp310-manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: torchinfo==1.8.0 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 65)) (1.8.0)
# Collecting torchvision==0.18.0 (from -r automathon-2024-B/requirements.txt (line 66))
#   Downloading torchvision-0.18.0-cp310-cp310-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting tornado==6.4 (from -r automathon-2024-B/requirements.txt (line 67))
#   Downloading tornado-6.4-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting tqdm==4.66.2 (from -r automathon-2024-B/requirements.txt (line 68))
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.7 MB/s eta 0:00:00
# Collecting traitlets==5.14.3 (from -r automathon-2024-B/requirements.txt (line 69))
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting typing_extensions==4.11.0 (from -r automathon-2024-B/requirements.txt (line 70))
#   Downloading typing_extensions-4.11.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting tzdata==2024.1 (from -r automathon-2024-B/requirements.txt (line 71))
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting urllib3==2.2.1 (from -r automathon-2024-B/requirements.txt (line 72))
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: wandb==0.16.6 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 73)) (0.16.6)
# Requirement already satisfied: wcwidth==0.2.13 in /opt/conda/lib/python3.10/site-packages (from -r automathon-2024-B/requirements.txt (line 74)) (0.2.13)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.3.0->-r automathon-2024-B/requirements.txt (line 63))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.3.0->-r automathon-2024-B/requirements.txt (line 63))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.3.0->-r automathon-2024-B/requirements.txt (line 63))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.3.0->-r automathon-2024-B/requirements.txt (line 63))
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.3.0->-r automathon-2024-B/requirements.txt (line 63))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.3.0->-r automathon-2024-B/requirements.txt (line 63))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.3.0->-r automathon-2024-B/requirements.txt (line 63))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.3.0->-r automathon-2024-B/requirements.txt (line 63))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.3.0->-r automathon-2024-B/requirements.txt (line 63))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.3.0->-r automathon-2024-B/requirements.txt (line 63))
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.3.0->-r automathon-2024-B/requirements.txt (line 63))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.3.0 (from torch==2.3.0->-r automathon-2024-B/requirements.txt (line 63))
#   Downloading triton-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb==0.16.6->-r automathon-2024-B/requirements.txt (line 73)) (69.0.3)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0->-r automathon-2024-B/requirements.txt (line 63))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Downloading appnope-0.1.4-py2.py3-none-any.whl (4.3 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (305 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 kB 10.7 MB/s eta 0:00:00
# Downloading debugpy-1.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 45.2 MB/s eta 0:00:00:00:01
# Downloading exceptiongroup-1.2.1-py3-none-any.whl (16 kB)
# Downloading filelock-3.13.4-py3-none-any.whl (11 kB)
# Downloading fonttools-4.51.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 58.5 MB/s eta 0:00:00:00:0100:01
# Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 8.6 MB/s eta 0:00:00
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 10.4 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.1 MB/s eta 0:00:00
# Downloading ipykernel-6.29.4-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.1/117.1 kB 6.1 MB/s eta 0:00:00
# Downloading ipython-8.24.0-py3-none-any.whl (816 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 816.5/816.5 kB 31.5 MB/s eta 0:00:00
# Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 6.5 MB/s eta 0:00:00
# Downloading jupyter_client-8.6.1-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 5.0 MB/s eta 0:00:00
# Downloading jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Downloading matplotlib-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 74.4 MB/s eta 0:00:00:00:010:01
# Downloading matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 45.9 MB/s eta 0:00:00:00:01
# Downloading packaging-24.0-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 2.2 MB/s eta 0:00:00
# Downloading parso-0.8.4-py2.py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.7/103.7 kB 5.6 MB/s eta 0:00:00
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 2.7 MB/s eta 0:00:00
# Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 64.7 MB/s eta 0:00:00:00:01
# Downloading platformdirs-4.2.1-py3-none-any.whl (17 kB)
# Downloading prompt_toolkit-3.0.43-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.1/386.1 kB 17.3 MB/s eta 0:00:00
# Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 13.1 MB/s eta 0:00:00
# Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 14.3 MB/s eta 0:00:00
# Downloading pyav-12.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.6/29.6 MB 47.2 MB/s eta 0:00:00:00:0100:01
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 4.9 MB/s eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 22.7 MB/s eta 0:00:00
# Downloading pyzmq-26.0.2-cp310-cp310-manylinux_2_28_x86_64.whl (919 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 920.0/920.0 kB 33.0 MB/s eta 0:00:00
# Downloading sentry_sdk-2.0.1-py2.py3-none-any.whl (266 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.8/266.8 kB 14.5 MB/s eta 0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading torch-2.3.0-cp310-cp310-manylinux1_x86_64.whl (779.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 1.7 MB/s eta 0:00:00:00:0100:01
# Downloading torchaudio-2.3.0-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 5.7 MB/s eta 0:00:000:00:01
# Downloading torchvision-0.18.0-cp310-cp310-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 20.9 MB/s eta 0:00:00:00:0100:01
# Downloading tornado-6.4-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.4/435.4 kB 3.8 MB/s eta 0:00:00:00:01
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 872.7 kB/s eta 0:00:00 0:00:01
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 917.6 kB/s eta 0:00:00a 0:00:01
# Downloading typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 3.9 MB/s eta 0:00:00:00:01
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 1.4 MB/s eta 0:00:00ta 0:00:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 70.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 55.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 28.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 5.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 5.1 MB/s eta 0:00:00:00:0100:01m
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 3.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 7.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 4.5 MB/s eta 0:00:00
# Downloading triton-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 7.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 58.7 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: pytz, urllib3, tzdata, typing_extensions, traitlets, tqdm, tornado, pyzmq, pyparsing, pyav, psutil, protobuf, prompt-toolkit, platformdirs, pillow, pexpect, parso, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, nest-asyncio, MarkupSafe, idna, fsspec, fonttools, filelock, exceptiongroup, debugpy, contourpy, appnope, triton, stack-data, sentry-sdk, nvidia-cusparse-cu12, nvidia-cudnn-cu12, matplotlib-inline, matplotlib, jupyter_core, Jinja2, GitPython, comm, nvidia-cusolver-cu12, jupyter_client, ipython, torch, ipykernel, torchvision, torchaudio
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2023.3.post1
#     Uninstalling pytz-2023.3.post1:
#       Successfully uninstalled pytz-2023.3.post1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.18
#     Uninstalling urllib3-1.26.18:
#       Successfully uninstalled urllib3-1.26.18
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2023.4
#     Uninstalling tzdata-2023.4:
#       Successfully uninstalled tzdata-2023.4
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.9.0
#     Uninstalling traitlets-5.9.0:
#       Successfully uninstalled traitlets-5.9.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.3.3
#     Uninstalling tornado-6.3.3:
#       Successfully uninstalled tornado-6.3.3
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 24.0.1
#     Uninstalling pyzmq-24.0.1:
#       Successfully uninstalled pyzmq-24.0.1
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.3
#     Uninstalling psutil-5.9.3:
#       Successfully uninstalled psutil-5.9.3
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.42
#     Uninstalling prompt-toolkit-3.0.42:
#       Successfully uninstalled prompt-toolkit-3.0.42
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.2.0
#     Uninstalling platformdirs-4.2.0:
#       Successfully uninstalled platformdirs-4.2.0
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.5.0
#     Uninstalling Pillow-9.5.0:
#       Successfully uninstalled Pillow-9.5.0
#   Attempting uninstall: pexpect
#     Found existing installation: pexpect 4.8.0
#     Uninstalling pexpect-4.8.0:
#       Successfully uninstalled pexpect-4.8.0
#   Attempting uninstall: parso
#     Found existing installation: parso 0.8.3
#     Uninstalling parso-0.8.3:
#       Successfully uninstalled parso-0.8.3
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.2.1
#     Uninstalling networkx-3.2.1:
#       Successfully uninstalled networkx-3.2.1
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.5.8
#     Uninstalling nest-asyncio-1.5.8:
#       Successfully uninstalled nest-asyncio-1.5.8
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.3
#     Uninstalling MarkupSafe-2.1.3:
#       Successfully uninstalled MarkupSafe-2.1.3
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.2.0
#     Uninstalling fsspec-2024.2.0:
#       Successfully uninstalled fsspec-2024.2.0
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.47.0
#     Uninstalling fonttools-4.47.0:
#       Successfully uninstalled fonttools-4.47.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.13.1
#     Uninstalling filelock-3.13.1:
#       Successfully uninstalled filelock-3.13.1
#   Attempting uninstall: exceptiongroup
#     Found existing installation: exceptiongroup 1.2.0
#     Uninstalling exceptiongroup-1.2.0:
#       Successfully uninstalled exceptiongroup-1.2.0
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.8.0
#     Uninstalling debugpy-1.8.0:
#       Successfully uninstalled debugpy-1.8.0
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.2.0
#     Uninstalling contourpy-1.2.0:
#       Successfully uninstalled contourpy-1.2.0
#   Attempting uninstall: stack-data
#     Found existing installation: stack-data 0.6.2
#     Uninstalling stack-data-0.6.2:
#       Successfully uninstalled stack-data-0.6.2
#   Attempting uninstall: sentry-sdk
#     Found existing installation: sentry-sdk 1.45.0
#     Uninstalling sentry-sdk-1.45.0:
#       Successfully uninstalled sentry-sdk-1.45.0
#   Attempting uninstall: matplotlib-inline
#     Found existing installation: matplotlib-inline 0.1.6
#     Uninstalling matplotlib-inline-0.1.6:
#       Successfully uninstalled matplotlib-inline-0.1.6
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.5
#     Uninstalling matplotlib-3.7.5:
#       Successfully uninstalled matplotlib-3.7.5
#   Attempting uninstall: jupyter_core
#     Found existing installation: jupyter_core 5.7.1
#     Uninstalling jupyter_core-5.7.1:
#       Successfully uninstalled jupyter_core-5.7.1
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 3.1.2
#     Uninstalling Jinja2-3.1.2:
#       Successfully uninstalled Jinja2-3.1.2
#   Attempting uninstall: GitPython
#     Found existing installation: GitPython 3.1.41
#     Uninstalling GitPython-3.1.41:
#       Successfully uninstalled GitPython-3.1.41
#   Attempting uninstall: comm
#     Found existing installation: comm 0.2.1
#     Uninstalling comm-0.2.1:
#       Successfully uninstalled comm-0.2.1
#   Attempting uninstall: jupyter_client
#     Found existing installation: jupyter_client 7.4.9
#     Uninstalling jupyter_client-7.4.9:
#       Successfully uninstalled jupyter_client-7.4.9
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.20.0
#     Uninstalling ipython-8.20.0:
#       Successfully uninstalled ipython-8.20.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.2+cpu
#     Uninstalling torch-2.1.2+cpu:
#       Successfully uninstalled torch-2.1.2+cpu
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.28.0
#     Uninstalling ipykernel-6.28.0:
#       Successfully uninstalled ipykernel-6.28.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.16.2+cpu
#     Uninstalling torchvision-0.16.2+cpu:
#       Successfully uninstalled torchvision-0.16.2+cpu
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.1.2+cpu
#     Uninstalling torchaudio-2.1.2+cpu:
#       Successfully uninstalled torchaudio-2.1.2+cpu
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-cv 0.8.2 requires keras-core, which is not installed.
# keras-nlp 0.9.3 requires keras-core, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# apache-beam 2.46.0 requires protobuf<4,>3.12.2, but you have protobuf 4.25.3 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 15.0.2 which is incompatible.
# beatrix-jupyterlab 2023.128.151533 requires jupyterlab~=3.6.0, but you have jupyterlab 4.1.6 which is incompatible.
# datasets 2.18.0 requires fsspec[http]<=2024.2.0,>=2023.1.0, but you have fsspec 2024.3.1 which is incompatible.
# fastai 2.7.14 requires torch<2.3,>=1.10, but you have torch 2.3.0 which is incompatible.
# gcsfs 2024.2.0 requires fsspec==2024.2.0, but you have fsspec 2024.3.1 which is incompatible.
# google-cloud-aiplatform 0.6.0a1 requires google-api-core[grpc]<2.0.0dev,>=1.22.2, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-automl 1.0.1 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 24.0 which is incompatible.
# google-cloud-bigquery 2.34.4 requires protobuf<4.0.0dev,>=3.12.0, but you have protobuf 4.25.3 which is incompatible.
# google-cloud-bigtable 1.7.3 requires protobuf<4.0.0dev, but you have protobuf 4.25.3 which is incompatible.
# google-cloud-datastore 1.15.5 requires protobuf<4.0.0dev, but you have protobuf 4.25.3 which is incompatible.
# google-cloud-vision 2.8.0 requires protobuf<4.0.0dev,>=3.19.0, but you have protobuf 4.25.3 which is incompatible.
# jupyterlab 4.1.6 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# kfp 2.5.0 requires protobuf<4,>=3.13.0, but you have protobuf 4.25.3 which is incompatible.
# kfp 2.5.0 requires urllib3<2.0.0, but you have urllib3 2.2.1 which is incompatible.
# kfp-pipeline-spec 0.2.2 requires protobuf<4,>=3.13.0, but you have protobuf 4.25.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.2 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# s3fs 2024.2.0 requires fsspec==2024.2.0, but you have fsspec 2024.3.1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorboard 2.15.1 requires protobuf<4.24,>=3.19.6, but you have protobuf 4.25.3 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.2.1 which is incompatible.
# tensorflow-metadata 0.14.0 requires protobuf<4,>=3.7, but you have protobuf 4.25.3 which is incompatible.
# tensorflow-transform 0.14.0 requires protobuf<4,>=3.7, but you have protobuf 4.25.3 which is incompatible.
# torchtext 0.16.2+cpu requires torch==2.1.2, but you have torch 2.3.0 which is incompatible.
# virtualenv 20.21.0 requires platformdirs<4,>=2.4, but you have platformdirs 4.2.1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed GitPython-3.1.43 Jinja2-3.1.3 MarkupSafe-2.1.5 appnope-0.1.4 comm-0.2.1 contourpy-1.2.1 debugpy-1.8.0 exceptiongroup-1.2.1 filelock-3.13.4 fonttools-4.51.0 fsspec-2024.3.1 idna-3.7 ipykernel-6.28.0 ipython-8.20.0 jupyter_client-8.6.0 jupyter_core-5.7.2 matplotlib-3.8.4 matplotlib-inline-0.1.6 nest-asyncio-1.5.8 networkx-3.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 packaging-24.0 parso-0.8.3 pexpect-4.9.0 pillow-10.3.0 platformdirs-4.2.1 prompt-toolkit-3.0.43 protobuf-3.20.3 psutil-5.9.7 pyav-12.0.5 pyparsing-3.1.2 pytz-2024.1 pyzmq-25.1.2 sentry-sdk-2.0.1 stack-data-0.6.3 torch-2.3.0 torchaudio-2.3.0 torchvision-0.18.0 tornado-6.4 tqdm-4.66.2 traitlets-5.14.3 triton-2.3.0 typing_extensions-4.11.0 tzdata-2024.1 urllib3-2.1.0

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchinfo import summary
import torch.optim as optim
import torchvision.io as io
import os
import json
from tqdm import tqdm
import csv
import timm
import wandb

from PIL import Image
import torchvision.transforms as transforms

# %%
class VideoDataset(Dataset):
    """
    This Dataset takes a video and returns a tensor of shape [10, 3, 256, 256]
    That is 10 colored frames of 256x256 pixels.
    """
    def __init__(
        self, root_dir, dataset_choice="train", nb_frames=10, trans=None
    ):
        super().__init__()
        self.dataset_choice = dataset_choice
        self.transforms = trans
        if  self.dataset_choice == "train":
            self.root_dir = os.path.join(root_dir, "dataset/train_dataset")
        elif  self.dataset_choice == "test":
            self.root_dir = os.path.join(root_dir, "dataset/test_dataset")
        elif  self.dataset_choice == "experimental":
            self.root_dir = os.path.join(root_dir, "dataset/experimental_dataset")
        else:
            raise ValueError("choice must be 'train', 'test' or 'experimental'")

        with open(os.path.join(root_dir, "dataset.csv"), 'r') as file:
            reader = csv.reader(file)
            # read dataset.csv with id,label columns to create
            # a dict which associated label: id
            self.ids = {row[1] : row[0] for row in reader}

        if self.dataset_choice == "test":
            self.data = None
        else:
            with open(os.path.join(self.root_dir, "metadata.json"), 'r') as file:
                self.data= json.load(file)
                self.data = {k : (torch.tensor(float(1)) if v == 'FAKE' else torch.tensor(float(0))) for k, v in self.data.items()}

        self.video_files = [f for f in os.listdir(self.root_dir) if f.endswith('.mp4')]
        
    def __len__(self):
        return len(self.video_files)

    def __getitem__(self, idx):
        video_path = os.path.join(self.root_dir, self.video_files[idx])
        video, audio, info = io.read_video(video_path, pts_unit='sec')
        
        video = video.permute(0,3,1,2)
        length = video.shape[0]
        video = video[[i*(length//(nb_frames)) for i in range(nb_frames)]]

        # resize the data into a reglar shape of 256x256 and normalize it
        #video = smart_resize(video, 256) / 255
        video = video / 255
        video = self._apply_transforms(video)

        ID = self.ids[self.video_files[idx]]
        if self.dataset_choice == "test":
            return video, ID
        else:
            label = self.data[self.video_files[idx]]
            return video, label, ID
        
    def _apply_transforms(self, stack):
        """apply the transforms to the stack of frames"""
        if self.transforms is None:
            return stack
        return self.transforms(stack)

# %%
import timm 

dataset_dir = "/kaggle/input/automathon-deepfake"
nb_frames   = 10

# grayscale and flip
trans = transforms.Compose([
        transforms.Grayscale(),
        torch.squeeze,
        transforms.RandomHorizontalFlip(),
    ])

experimental_dataset = VideoDataset(
    dataset_dir,
    dataset_choice="experimental",
    nb_frames=nb_frames,
    trans=trans
)

train_dataloader = DataLoader(experimental_dataset, batch_size=64, shuffle=True)
model = timm.create_model("resnet18", pretrained=True, num_classes=2, in_chans=nb_frames)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
loss_fn = nn.BCELoss()
            
trainer = Trainer(model, train_dataloader, loss_fn, optimizer, None)
trainer.train(1)
# Out:
# model.safetensors:   0%|          | 0.00/379M [00:00<?, ?B/s]
# Beit(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(10, 768, kernel_size=(16, 16), stride=(16, 16))
#     (norm): Identity()
#   )
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (blocks): ModuleList(
#     (0-11): 12 x Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=False)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path2): Identity()
#     )
#   )
#   (norm): Identity()
#   (fc_norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   (head_drop): Dropout(p=0.0, inplace=False)
#   (head): Linear(in_features=768, out_features=2, bias=True)
# )
